# %% [markdown]
# NumPy (Numerical Python)
# Used for fast numerical computations with arrays.
#
# What It Does:
# Supports large, multi-dimensional arrays and matrices
# Has mathematical functions like mean, std, dot product, etc.

# %%
import numpy as np
arr = np.array([5,7,9])
print("Array = ",arr)
print("Mean = ",arr.mean())
print("Standard Deviation = ",arr.std())
# Out:
# Array =  [5 7 9]
# Mean =  7.0
# Standard Deviation =  1.632993161855452

# %% [markdown]
# Pandas (Python Data Analysis Library)
# Used for data manipulation and analysis.
#
# What It Does:
# Lets you work with DataFrames (tabular data like Excel)
# Easy to read, clean, and process datasets
#
# pd.DataFrame() is a Pandas function that turns your dictionary into a DataFrame — a table like in Excel.
#
# It organizes your data into rows and columns:
# index	Name	     Age
# 0	    Alice	     25
# 1	    Bob	       30
# 2	    Charlie	   22
#
# Store the resulting table into a variable called df

# %%
import pandas as pd
data={'Name' : ["Karthika","Deepa","Ezhil"],
      'Age' : [22,50,26]}

df=pd.DataFrame(data)
print(df)
print("\n")
print("Summary",df.describe())
print("\n")
print(df['Name'])
print("\n")
print(df[df['Age']>=50])
# Out:
#        Name  Age
# 0  Karthika   22
# 1     Deepa   50
# 2     Ezhil   26
#
#
# Summary              Age
# count   3.000000
# mean   32.666667
# std    15.143756
# min    22.000000
# 25%    24.000000
# 50%    26.000000
# 75%    38.000000
# max    50.000000
#
#
# 0    Karthika
# 1       Deepa
# 2       Ezhil
# Name: Name, dtype: object
#
#
#     Name  Age
# 1  Deepa   50

# %% [markdown]
# Matplotlib
# 🔹 The base library for creating visualizations in Python.
#
# ✅ What It Does:
# Line charts, bar charts, scatter plots, pie charts, etc.
#
# Seaborn is built on top of it
#
# pyplot is a module inside matplotlib that makes it easy to create plots using simple functions — kind of like using a "paintbrush" for charts

# %%
import matplotlib.pyplot as plt

x=[1,2,3]
y=[2,4,6]

plt.plot(x,y)   #line chart
plt.title("line chart")
plt.xlabel("xx")
plt.ylabel("yy")
plt.show()

plt.bar(x,y)
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# Seaborn
# 🔹 A data visualization library based on matplotlib — makes plots beautiful and easy.
#
# ✅ What It Does:
# Used for statistical plots (e.g., barplots, histograms, pairplots)
#
# Works well with pandas DataFrames

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
data = {
          'fruits' : ['apple','orrange','grapes'],
          'count' : [5,10,6]
       }

df=pd.DataFrame(data)
sns.barplot(x='fruits' , y='count' , data=df)

plt.show()

# %% [markdown]
# Scikit-learn is a powerful and easy-to-use Python library that helps you build machine learning models quickly and efficiently.
#
# To provide tools to train, test, and evaluate machine learning models using just a few lines of code.
#
# from sklearn.datasets import load_iris
# This line imports the Iris dataset, which is a small, built-in dataset in Scikit-learn.
#
# from sklearn.model_selection import train_test_split
# This function splits your data into two parts:
# Training data ,Testing data
#
# from sklearn.neighbors import KNeighborsClassifier
# This imports the K-Nearest Neighbors (KNN) algorithm.
# KNN is a simple machine learning method used for classification (like predicting flower type).
# ✅ You will use this to train your model.
#
# from sklearn.metrics import accuracy_score
# This function is used to check how accurate your model is.
# It compares your model’s predictions with the actual answers.
#
# iris.data	The actual data from the Iris dataset (numbers only)
# columns=iris.feature_names	Names for each column (like "sepal length", etc.)

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import pandas as pd

iris=load_iris()
df=pd.DataFrame(iris.data,columns=iris.feature_names)
print(df)

df['species'] = iris.target    # This creates a new column in the DataFrame named "species"
                               # iris.target	This is a list of numbers representing flower species: 0 = setosa, 1 = versicolor, 2 = virginica

df.head()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]
# ...

# %%
#Split data into training and testing (80% train, 20% test)
# X = features(like sepal petal measurement), y = labels(output : type of flowers 0 - setosa , 1-versicolor , 2-virginica)

x=iris.data
y=iris.target

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1) #Whenever you use train_test_split, it randomly shuffles the data before splitting it.
                                                                                 #If you don't set random_state, the split will be different each time you run the code.
print("Training Features")
print(x_train[:5])
print("\nTraining Labels")
print(y_train[:5])

print("\n\n\nTesting Features")
print(x_test[:5])
print("\nTesting Labels")
print(y_test[:5])
# Out:
# Training Features
# [[6.1 3.  4.6 1.4]
#  [7.7 3.  6.1 2.3]
#  [5.6 2.5 3.9 1.1]
#  [6.4 2.8 5.6 2.1]
#  [5.8 2.8 5.1 2.4]]
#
# Training Labels
# [1 2 1 2 2]
#
#
#
# Testing Features
# [[5.8 4.  1.2 0.2]
#  [5.1 2.5 3.  1.1]
#  [6.6 3.  4.4 1.4]
#  [5.4 3.9 1.3 0.4]
#  [7.9 3.8 6.4 2. ]]
#
# Testing Labels
# [0 1 1 0 2]

# %%
#Train a model using KNN
model=KNeighborsClassifier(n_neighbors=3)  #When predicting a flower, look at the 3 closest neighbors in the training data and use their majority class (species) to decide.
model.fit(x_train,y_train)  #	Train the model using training features and labels
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
# Predict on test data
y_pred = model.predict(x_test)

print("Predicted Labels")
print(y_pred[:5])
print("\nActual Labels")
print(y_test[:5])

accuracy=accuracy_score(y_test,y_pred)
print("\n\nAccuracy = ", accuracy)
# Out:
# Predicted Labels
# [0 1 1 0 2]
#
# Actual Labels
# [0 1 1 0 2]
#
#
# Accuracy =  1.0
